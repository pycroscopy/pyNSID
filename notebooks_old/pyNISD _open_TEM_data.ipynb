# %% [markdown]
# # Open TEM data files with pyNSID
#
# A fast  introduction to an easy to use but comprehensive data format.
#
# pyNSID is based on pyUSID and part of pycroscopy
#
# pyNSID has two forms.
# - a front end that is based on dask
# - a back end to store the data in an hdf5 dataset
#
# First we load the usual suspects

# %%
# import matplotlib and numpy
#                       use "inline" instead of "notebook" for non-interactive plots
# %pylab --no-import-all notebook 

# import pyNSID (the basic way at this point)
import os, sys
sys.path.append('../../')
import pyNSID as nsid

import file_tools_nsid as ft
# Out:
# Populating the interactive namespace from numpy and matplotlib
# windows

# %% [markdown]
# ## Load data
# We load a data file and get a dictionary

# %%
filename = ft.openfile_dialog()
path, file_name = os.path.split(filename)
basename, extension = os.path.splitext(file_name)
tags = ft.open_file(filename)
# Out:
# not_instance

# %% [markdown]
# ## Make an NSID Dataset out of it:

# %%
def make_dask_dataset(tags):
    tags_dimension, main_data = ft.get_dimension_tags(tags)
    data = nsid.NSIDask.from_array(main_data)
    for index, dimension in tags_dimension.items():
        data.set_dimension(index, dimension)
        
    data.quantity = 'intensity'
    data.units="counts"
    data.data_type = tags['data_type']
    data.modality = 'STEM/TEM'
    if 'spectrum' in data.data_type:
        if 'EDS'  in  data.data_type:
            data.source= 'EDS'
        else:
            data.source= 'EELS'
    else:
        data.source= 'detector'
    
    
    data.original_metadata = ft.flatten_directory(tags['original_metadata'])

    if 'aberrations' in tags:
        #set_attribute('aberrations')
        data.aberrations =  tags['aberrations']
    if 'annotations' in tags:
        data.annotations =  tags['annotations']

    if 'image' in tags:
        data.attrs.update(tags['image'])

    for key, value in tags.items():
        if isinstance(value,dict):
            pass
        elif 'data' == key:
            pass
        else:
            data.attrs[key]= value
            
    return data

# %%
data = ft.make_dask_dataset(tags)
# Out:
# 0
# 1
# 2

# %% [markdown]
# We can now access these additional dimensional information

# %%
print(data.x)
print('units of y-axis :',data.y.units)
print('quantity of x-axis :',data.x.quantity)
print('values of y-axis :',data.y.values)
# Out:
# x - distance (nm): [ 0.       0.03125  0.0625   0.09375  0.125    0.15625  0.1875   0.21875
#   0.25     0.28125  0.3125   0.34375  0.375    0.40625  0.4375   0.46875
#   0.5      0.53125  0.5625   0.59375  0.625    0.65625  0.6875   0.71875
#   0.75     0.78125  0.8125   0.84375  0.875    0.90625  0.9375   0.96875
#   1.       1.03125  1.0625   1.09375  1.125    1.15625  1.1875   1.21875
#   1.25     1.28125  1.3125   1.34375  1.375    1.40625  1.4375   1.46875
#   1.5      1.53125  1.5625   1.59375  1.625    1.65625  1.6875   1.71875
#   1.75     1.78125  1.8125   1.84375  1.875    1.90625  1.9375   1.96875
#   2.       2.03125  2.0625   2.09375  2.125    2.15625  2.1875   2.21875
#   2.25     2.28125  2.3125   2.34375  2.375    2.40625  2.4375   2.46875
#   2.5      2.53125  2.5625   2.59375  2.625    2.65625  2.6875   2.71875
#   2.75     2.78125  2.8125   2.84375  2.875    2.90625  2.9375   2.96875
#   3.       3.03125  3.0625   3.09375  3.125    3.15625  3.1875   3.21875
# %% [markdown]
# ## Plotting
# Because we specified the x and y axis as having a dimension_type of ``spatial``, we can already use this information and plot the data as image;
#
# This function is available also in the NSID dask dataset. (TODO)

# %%
def plot_image(data):
    """
    plotting of data according to two axis marked as 'spatial' in the dimensions
    """
    selection = []
    image_dims = []
    for  dim, axis in data.axes.items():
        if axis.dimension_type == 'spatial':
            selection.append(slice(None))
            image_dims.append(dim)
        else:
            selection.append(slice(0,1))
    if len(image_dims) != 2:
        raise ValueError('We need two dimensions with dimension_type spatial to plot an image')

    plt.figure()
    plt.title(data.title)
    img = plt.imshow(data[tuple(selection)].T, extent = data.get_extent(image_dims))
    plt.xlabel(f"{data.x.quantity} [{data.x.units}]")
    plt.ylabel(f"{data.y.quantity} [{data.y.units}]")
    cbar = plt.colorbar(img)
    cbar.set_label(f"{data.quantity} [{data.units}]")

    plt.show()

plot_image(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9fa7f8c7b2f3> in <module>
#      24     plt.show()
#      25
# ---> 26 plot_image(data)
#
# NameError: name 'data' is not defined

# %% [markdown]
# ## Other Metadata
# There are metadata in the attrs attribute of the data now

# %%
print(data.attrs.keys())
# Out:
# dict_keys(['exposure', 'pixel_time_us', 'ac_line_sync', 'rotation_deg', 'BP1^VOACurrent', 'EHT', 'NionCCD^CamCurrent', 'PL4', 'PMTBF2_gain', 'PMTBF_gain', 'PMTDF_gain', 'S_EELS', 'StageOutA', 'StageOutB', 'StageOutX', 'StageOutY', 'StageOutZ', 'SuperFEG_EmissionMultiplier', 'SuperFEG_FocalLengthTarget', 'SuperFEG_^VariableFocus', 'filename', 'path', 'extension', 'basename', 'shape', 'file_type', 'original_name', 'created_date', 'created_time', 'pixel_size', 'FOV', 'unit', 'acceleration_voltage', 'microscope', 'type', 'initial_file', 'data_type'])

# %% [markdown]
# All the original metadata are stored in the ``original_metadata`` attribute of NSIDask dataset.

# %%
print(data.original_metadata.keys())
# Out:
# dict_keys(['type', 'uuid', 'created', 'data_shape', 'data_dtype', 'is_sequence', 'collection_dimension_count', 'datum_dimension_count', 'intensity_calibration.offset', 'intensity_calibration.scale', 'intensity_calibration.units', 'dim-offset-0', 'dim-scale-0', 'dim-units-0', 'dim-offset-1', 'dim-scale-1', 'dim-units-1', 'dim-offset-2', 'dim-scale-2', 'dim-units-2', 'data_modified', 'timezone', 'timezone_offset', 'metadata.hardware_source.ImageScanned:BP1.^VOACurrent', 'metadata.hardware_source.ImageScanned:C1 ConstW', 'metadata.hardware_source.ImageScanned:C10', 'metadata.hardware_source.ImageScanned:C12.a', 'metadata.hardware_source.ImageScanned:C12.b', 'metadata.hardware_source.ImageScanned:C21.a', 'metadata.hardware_source.ImageScanned:C21.b', 'metadata.hardware_source.ImageScanned:C23.a', 'metadata.hardware_source.ImageScanned:C23.b', 'metadata.hardware_source.ImageScanned:C30', 'metadata.hardware_source.ImageScanned:C32.a', 'metadata.hardware_source.ImageScanned:C32.b', 'metadata.hardware_source.ImageScanned:C34.a', 'metadata.hardware_source.ImageScanned:C34.b', 'metadata.hardware_source.ImageScanned:C41.a', 'metadata.hardware_source.ImageScanned:C41.b', 'metadata.hardware_source.ImageScanned:C43.a', 'metadata.hardware_source.ImageScanned:C43.b', 'metadata.hardware_source.ImageScanned:C45.a', 'metadata.hardware_source.ImageScanned:C45.b', 'metadata.hardware_source.ImageScanned:C50', 'metadata.hardware_source.ImageScanned:C52.a', 'metadata.hardware_source.ImageScanned:C52.b', 'metadata.hardware_source.ImageScanned:C54.a', 'metadata.hardware_source.ImageScanned:C54.b', 'metadata.hardware_source.ImageScanned:C56.a', 'metadata.hardware_source.ImageScanned:C56.b', 'metadata.hardware_source.ImageScanned:EHT', 'metadata.hardware_source.ImageScanned:NionCCD.^CamCurrent', 'metadata.hardware_source.ImageScanned:PL4', 'metadata.hardware_source.ImageScanned:PMTBF2_gain', 'metadata.hardware_source.ImageScanned:PMTBF_gain', 'metadata.hardware_source.ImageScanned:PMTDF_gain', 'metadata.hardware_source.ImageScanned:S_EELS', 'metadata.hardware_source.ImageScanned:StageOutA', 'metadata.hardware_source.ImageScanned:StageOutB', 'metadata.hardware_source.ImageScanned:StageOutX', 'metadata.hardware_source.ImageScanned:StageOutY', 'metadata.hardware_source.ImageScanned:StageOutZ', 'metadata.hardware_source.ImageScanned:SuperFEG_EmissionMultiplier', 'metadata.hardware_source.ImageScanned:SuperFEG_FocalLengthTarget', 'metadata.hardware_source.ImageScanned:SuperFEG_^VariableFocus', 'metadata.hardware_source.MagBoard 0 DAC 0', 'metadata.hardware_source.MagBoard 0 DAC 1', 'metadata.hardware_source.MagBoard 0 DAC 10', 'metadata.hardware_source.MagBoard 0 DAC 11', 'metadata.hardware_source.MagBoard 0 DAC 2', 'metadata.hardware_source.MagBoard 0 DAC 3', 'metadata.hardware_source.MagBoard 0 DAC 4', 'metadata.hardware_source.MagBoard 0 DAC 5', 'metadata.hardware_source.MagBoard 0 DAC 6', 'metadata.hardware_source.MagBoard 0 DAC 7', 'metadata.hardware_source.MagBoard 0 DAC 8', 'metadata.hardware_source.MagBoard 0 DAC 9', 'metadata.hardware_source.MagBoard 0 Relay', 'metadata.hardware_source.MagBoard 1 DAC 0', 'metadata.hardware_source.MagBoard 1 DAC 1', 'metadata.hardware_source.MagBoard 1 DAC 10', 'metadata.hardware_source.MagBoard 1 DAC 11', 'metadata.hardware_source.MagBoard 1 DAC 2', 'metadata.hardware_source.MagBoard 1 DAC 3', 'metadata.hardware_source.MagBoard 1 DAC 4', 'metadata.hardware_source.MagBoard 1 DAC 5', 'metadata.hardware_source.MagBoard 1 DAC 6', 'metadata.hardware_source.MagBoard 1 DAC 7', 'metadata.hardware_source.MagBoard 1 DAC 8', 'metadata.hardware_source.MagBoard 1 DAC 9', 'metadata.hardware_source.MagBoard 1 Relay', 'metadata.hardware_source.ac_line_sync', 'metadata.hardware_source.calibration_style', 'metadata.hardware_source.center_x_nm', 'metadata.hardware_source.center_y_nm', 'metadata.hardware_source.channel_id', 'metadata.hardware_source.flyback_time_us', 'metadata.hardware_source.fov_nm', 'metadata.hardware_source.line_time ...

# %% [markdown]
# ## Save to file
# We created a fully functioning NSID dataset. Now let's save it.
# We need a hdf5 file and a group in that file, which we hand over to the ``to_hdf5`` function.

# %%
import h5py
h5_file = h5py.File('test.hf5', mode='a')
if 'Measurement_000/Channel_000' in h5_file:
    del h5_file['Measurement_000/Channel_000']
h5_group = h5_file.create_group('Measurement_000/Channel_000')

# %%
data.to_hdf5(h5_group)

# %% [markdown]
# Let's look at the data file

# %%
 nsid.hdf_utils.print_tree(h5_file)
# Out:
# /
# ├ Measurement_000
#   ---------------
#   ├ Channel_000
#     -----------
#     ├ aberrations
#       -----------
#     ├ nDim_Data
#     ├ original_metadata
#       -----------------
#     ├ x
#     ├ y
#     ├ z

# %% [markdown]
# We see that we have an additional attribute aberrations.
#
# This is an attribute we set additionally as
#
# `data.aberrations = {tags['aberrations']}`
#
# Let's look what's in it:

# %%
print(data.aberrations)
# Out:
# {'C1 ConstW': 338000000.0, 'C10': 0.0, 'C12a': 0.0, 'C12b': 0.0, 'C21a': 52.3255, 'C21b': -168.525, 'C23a': -35.9977, 'C23b': -27.1277, 'C30': 422.104, 'C32a': 3968.6499999999996, 'C32b': 454.836, 'C34a': 1328.2, 'C34b': 637.626, 'C41a': 16974.899999999998, 'C41b': 349596.0, 'C43a': 137586.0, 'C43b': -5281.71, 'C45a': 34934.4, 'C45b': -23469.199999999997, 'C50': 2052560.0000000002, 'C52a': -7101740.0, 'C52b': 2270730.0, 'C54a': -3121730.0, 'C54b': -1168900.0, 'C56a': -369928.0, 'C56b': 207238.0, 'source_size': 0.051}

# %% [markdown]
# And we close the file

# %%
h5_file.close()

# %% [markdown]
# ## Open hdf5 NSID dataset as NSID-dask

# %%
import h5py
h5_file = h5py.File('test.hf5', mode='a')

# %%
nsid.hdf_utils.print_tree(h5_file)
# Out:
# /
# ├ Measurement_000
#   ---------------
#   ├ Channel_000
#     -----------
#     ├ aberrations
#       -----------
#     ├ nDim_Data
#     ├ original_metadata
#       -----------------
#     ├ title
#     ├ x
#     ├ y
#     ├ z

# %%
dset_list  =  nsid.io.hdf_utils.find_dataset(h5_file['Measurement_000/Channel_000'], 'nDim_Data')
data2 = nsid.NSIDask.from_hdf5(dset_list[0])

plot_image(data2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Accessing data from NSID and dask

# %%
dset = dset_list[0]

print(dset.parent['x'].attrs['dimension_type'])
print(data2.dim_1.dimension_type)
print(data2.x)
print(dset.dims[1].label)
# Out:
# spatial
# spatial
# x - distance (nm): [ 0.       0.03125  0.0625   0.09375  0.125    0.15625  0.1875   0.21875
#   0.25     0.28125  0.3125   0.34375  0.375    0.40625  0.4375   0.46875
#   0.5      0.53125  0.5625   0.59375  0.625    0.65625  0.6875   0.71875
#   0.75     0.78125  0.8125   0.84375  0.875    0.90625  0.9375   0.96875
#   1.       1.03125  1.0625   1.09375  1.125    1.15625  1.1875   1.21875
#   1.25     1.28125  1.3125   1.34375  1.375    1.40625  1.4375   1.46875
#   1.5      1.53125  1.5625   1.59375  1.625    1.65625  1.6875   1.71875
#  11.25    11.28125 11.3125  11.34375 11.375   11.40625 11.4375  11.46875
#  11.5     11.53125 11.5625  11.59375 11.625   11.65625 11.6875  11.71875
#  11.75    11.78125 11.8125  11.84375 11.875   11.90625 11.9375  11.96875
#  12.      12.03125 12.0625  12.09375 12.125   12.15625 12.1875  12.21875
#  12.25    12.28125 12.3125  12.34375 12.375   12.40625 12.4375  12.46875
#  12.5     12.53125 12.5625  12.59375 12.625   12.65625 12.6875  12.71875
#  12.75    12.78125 12.8125  12.84375 12.875   12.90625 12.9375  12.96875
#  13.      13.03125 13.0625  13.09375 13.125   13.15625 13.1875  13.21875
#  13.25    13.28125 13.3125  13.34375 13.375   13.40625 13.4375  13.46875
#  13.5     13.53125 13.5625  13.59375 13.625   13.65625 13.6875  13.71875
#  13.75    13.78125 13.8125  13.84375 13.875   13.90625 13.9375  13.96875
#  14.      14.03125 14.0625  14.09375 14.125   14.15625 14.1875  14.21875
#  14.25    14.28125 14.3125  14.34375 14.375   14.40625 14.4375  14.46875
#  14.5     14.53125 14.5625  14.59375 14.625   14.65625 14.6875  14.71875
#  14.75    14.78125 14.8125  14.84375 14.875   14.90625 14.9375  14.96875
#  15.      15.03125 15.0625  15.09375 15.125   15.15625 15.1875  15.21875
#  15.25    15.28125 15.3125  15.34375 15.375   15.40625 15.4375  15.46875
#  15.5     15.53125 15.5625  15.59375 15.625   15.65625 15.6875  15.71875
#  15.75    15.78125 15.8125  15.84375 15.875   15.90625 15.9375  15.96875]
# x

# %% [markdown]
# And we close the file again.

# %%
h5_file.close()

# %%
import importlib
importlib.reload(ft)
data3 = ft.h5_open_file('test.hf5')

# %%
plot_image(data3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(data3.original_metadata)
# Out:
# {'category': 'persistent', 'collection_dimension_count': 0, 'created': '2020-03-23T14:30:58.738377', 'data_dtype': 'float32', 'data_modified': '2020-03-23T14:30:58.753998', 'data_shape': array([ 25, 512, 512]), 'datum_dimension_count': 2, 'dim-offset-0': 0.0, 'dim-offset-1': -8.0, 'dim-offset-2': -8.0, 'dim-scale-0': 1.0, 'dim-scale-1': 0.03125, 'dim-scale-2': 0.03125, 'dim-units-0': '', 'dim-units-1': 'nm', 'dim-units-2': 'nm', 'intensity_calibration.offset': 0.0, 'intensity_calibration.scale': 1.0, 'intensity_calibration.units': '', 'is_sequence': True, 'metadata.hardware_source.ImageScanned:BP1.^VOACurrent': 2.02867e-09, 'metadata.hardware_source.ImageScanned:C1 ConstW': 0.338, 'metadata.hardware_source.ImageScanned:C10': 7.627e-08, 'metadata.hardware_source.ImageScanned:C12.a': 5.53324e-09, 'metadata.hardware_source.ImageScanned:C12.b': 2.77692e-09, 'metadata.hardware_source.ImageScanned:C21.a': 5.23255e-08, 'metadata.hardware_source.ImageScanned:C21.b': -1.68525e-07, 'metadata.hardware_source.ImageScanned:C23.a': -3.59977e-08, 'metadata.hardware_source.ImageScanned:C23.b': -2.71277e-08, 'metadata.hardware_source.ImageScanned:C30': 4.22104e-07, 'metadata.hardware_source.ImageScanned:C32.a': 3.96865e-06, 'metadata.hardware_source.ImageScanned:C32.b': 4.54836e-07, 'metadata.hardware_source.ImageScanned:C34.a': 1.3282e-06, 'metadata.hardware_source.ImageScanned:C34.b': 6.37626e-07, 'metadata.hardware_source.ImageScanned:C41.a': 1.69749e-05, 'metadata.hardware_source.ImageScanned:C41.b': 0.000349596, 'metadata.hardware_source.ImageScanned:C43.a': 0.000137586, 'metadata.hardware_source.ImageScanned:C43.b': -5.28171e-06, 'metadata.hardware_source.ImageScanned:C45.a': 3.49344e-05, 'metadata.hardware_source.ImageScanned:C45.b': -2.34692e-05, 'metadata.hardware_source.ImageScanned:C50': 0.00205256, 'metadata.hardware_source.ImageScanned:C52.a': -0.00710174, 'metadata.hardware_source.ImageScanned:C52.b': 0.00227073, 'metadata.hardware_source.ImageScanned:C54.a': -0.00312173, 'metadata.hardware_source.ImageScanned:C54.b': -0.0011689, 'metadata.hardware_source.ImageScanned:C56.a': -0.000369928, 'metadata.hardware_source.ImageScanned:C56.b': 0.000207238, 'metadata.hardware_source.ImageScanned:EHT': 200000.0, 'metadata.hardware_source.ImageScanned:NionCCD.^CamCurrent': -1.65114e-11, 'metadata.hardware_source.ImageScanned:PL4': 1.00002, 'metadata.hardware_source.ImageScanned:PMTBF2_gain': 4621.0, 'metadata.hardware_source.ImageScanned:PMTBF_gain': 1280000.0, 'metadata.hardware_source.ImageScanned:PMTDF_gain': 10384300.0, 'metadata.hardware_source.ImageScanned:S_EELS': 0.0, 'metadata.hardware_source.ImageScanned:StageOutA': 0.0916997, 'metadata.hardware_source.ImageScanned:StageOutB': -0.0207911, 'metadata.hardware_source.ImageScanned:StageOutX': 0.000108197, 'metadata.hardware_source.ImageScanned:StageOutY': 0.000381893, 'metadata.hardware_source.ImageScanned:StageOutZ': 0.000115, 'metadata.hardware_source.ImageScanned:SuperFEG_EmissionMultiplier': 1.0, 'metadata.hardware_source.ImageScanned:SuperFEG_FocalLengthTarget': 0.00275, 'metadata.hardware_source.ImageScanned:SuperFEG_^VariableFocus': 1.0, 'metadata.hardware_source.MagBoard 0 DAC 0': 0.0, 'metadata.hardware_source.MagBoard 0 DAC 1': 0.0, 'metadata.hardware_source.MagBoard 0 DAC 10': 7488.0, 'metadata.hardware_source.MagBoard 0 DAC 11': 61417.0, 'metadata.hardware_source.MagBoard 0 DAC 2': 0.0, 'metadata.hardware_source.MagBoard 0 DAC 3': 0.0, 'metadata.hardware_source.MagBoard 0 DAC 4': 58048.0, 'metadata.hardware_source.MagBoard 0 DAC 5': 3969.0, 'metadata.hardware_source.MagBoard 0 DAC 6': 53183.0, 'metadata.hardware_source.MagBoard 0 DAC 7': 6794.0, 'metadata.hardware_source.MagBoard 0 DAC 8': 53183.0, 'metadata.hardware_source.MagBoard 0 DAC 9': 6547.0, 'metadata.hardware_source.MagBoard 0 Relay': 32.0, 'metadata.hardware_source.MagBoard 1 DAC 0': 0.0, 'metadata.hardware_source.MagBoard 1 DAC 1': 0.0, 'metadata.hardware_source.MagBoard 1 DAC 10': 27997.0, 'metadata.hardware_s ...
